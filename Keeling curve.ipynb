# %%
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
from matplotlib.ticker import ScalarFormatter
from matplotlib.animation import FuncAnimation
import pandas as pd
from scipy.interpolate import UnivariateSpline
from matplotlib.font_manager import FontProperties
from scipy.interpolate import make_interp_spline
from scipy.ndimage import gaussian_filter1d

# %%
# Importing the data
nasa_data = pd.read_csv('NASA co2_mm_mlo.csv')
temp_anomaly = pd.read_csv('Annual_Surface_Temperature_Change.csv')
world_temperature_change = [0.211, 0.038, 0.168,	-0.246,	-0.223,	0.201,	-0.117,	-0.126,	-0.092,	0.15,	-0.093,	-0.199,	0.269,	-0.181,	0.088,	-0.314,	0.269,	0.001,	0.226,	0.332,	0.443,	0.086,	0.46,
                            0.127,	-0.031,	0.242,	0.403,	0.558, 0.331,	0.639,	0.468,	0.184,	0.348,	0.507,	0.835,	0.355,	0.656,	0.993,	0.783,	0.728,	0.834,	1.021,	0.893,	0.913,	1.095,	0.99,
                            1.195,	0.935,	0.957,	1.219,	0.921,  1.074,	1.016,	1.053,	1.412,	1.66,	1.429,	1.29,	1.444,	1.711,	1.447,	1.394]
world_temperature_change_years = ['1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', 
                                  '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000',' 2001', '2002', '2003', '2004', 
                                  '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022']


# Setting the x and y axes
x1 = nasa_data['year']
x2 = world_temperature_change_years

y11 = nasa_data['monthly_average']
y12 = nasa_data['de-seasonalized']
y2 = world_temperature_change_years

gaussian_weighted_avg = gaussian_filter1d(world_temperature_change, sigma=2)



# Plotting the data 
# plt.plot(x1, y11)
# plt.plot(x1, y12)
plt.plot(world_temperature_change_years, world_temperature_change, label='Temperature Change')
plt.plot(world_temperature_change_years, gaussian_weighted_avg, label='Gaussian Weighted Avg')
plt.xlabel('Years')
plt.ylabel('Temperature Anomaly')
plt.title('World Temperature Change Over Time')
plt.xticks(rotation=90)
plt.show()

# %%
nasa_data = pd.read_csv('NASA co2_mm_mlo.csv')

x1 = nasa_data['year']
y11 = nasa_data['monthly_average']
y12 = nasa_data['de-seasonalized']

plt.plot(x1, y11)
# plt.plot(x1, y12)
plt.xlabel("Years")
plt.ylabel("CO2 change")
plt.show()

# %%
nasa_data = pd.read_csv('NASA co2_mm_mlo.csv')

x1 = nasa_data['year']
y11 = nasa_data['monthly_average']
y12 = nasa_data['de-seasonalized']
world_temperature_change = [0.211, 0.038, 0.168,	-0.246,	-0.223,	0.201,	-0.117,	-0.126,	-0.092,	0.15,	-0.093,	-0.199,	0.269,	-0.181,	0.088,	-0.314,	0.269,	0.001,	0.226,	0.332,	0.443,	0.086,	0.46,
                            0.127,	-0.031,	0.242,	0.403,	0.558, 0.331,	0.639,	0.468,	0.184,	0.348,	0.507,	0.835,	0.355,	0.656,	0.993,	0.783,	0.728,	0.834,	1.021,	0.893,	0.913,	1.095,	0.99,
                            1.195,	0.935,	0.957,	1.219,	0.921,  1.074,	1.016,	1.053,	1.412,	1.66,	1.429,	1.29,	1.444,	1.711,	1.447,	1.394]
world_temperature_change_years = list(range(1961, 2023))
# world_temperature_change_years = ['1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', 
#                                   '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000',' 2001', '2002', '2003', '2004', 
#                                   '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022']


gaussian_weighted_avg = gaussian_filter1d(world_temperature_change, sigma=2)

#Putting the 2 together 
fig, ax1 = plt.subplots()
ax2 = ax1.twinx()
ax2.plot(x1, y11, color = 'black')
ax1.plot(world_temperature_change_years, world_temperature_change, label='Temperature Change')
ax1.plot(world_temperature_change_years, gaussian_weighted_avg, label='Gaussian Weighted Avg')
plt.show()
